# %% [markdown]
# ## Objetivo
#
# Este notebook implementa um Algoritmo Genético (GA) para otimizar os hiperparâmetros
# do modelo de Regressão Logística definido na Fase 1.
#
# O GA busca maximizar a métrica de *recall*, priorizando a detecção correta de pacientes
# diabéticos, conforme discutido anteriormente.

# %% [markdown]
# ### Carregar bibliotecas e dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

dataset = pd.read_csv("../dados/processados/processado_diabetes.csv")

X = dataset.drop("Outcome", axis=1)
y = dataset["Outcome"]
